# %%
# Framework Document

if 'Framework' in App.listDocuments():
    App.closeDocument('Framework')

App.newDocument('Framework')
App.ActiveDocument.saveAs("./Framework/Framework.FCStd")

App.openDocument('./Sketches/Sketches.FCStd')

App.setActiveDocument('Framework')

# %%
# PartDesign Workbench

Gui.ActiveDocument.ActiveView.viewDefaultOrientation()
Gui.ActiveDocument.ActiveView.setCameraType("Perspective")
Gui.activateWorkbench("PartDesignWorkbench")

# %% [markdown]
# # Square Tube Profile Sketch

# %%
# SquareTubeProfileSketch

if App.ActiveDocument.getObject('SquareTubeProfileSketch'):
    App.ActiveDocument.removeObject('SquareTubeProfileSketch')
    App.ActiveDocument.recompute()

App.ActiveDocument.addObject('App::Link', 'SquareTubeProfileSketch')
App.ActiveDocument.getObject('SquareTubeProfileSketch').LinkedObject = App.getDocument('Sketches').getObject('SquareTubeProfileSketch')
App.ActiveDocument.recompute()

Gui.SendMsgToActiveView("ViewFit")

# %% [markdown]
# # Square Tube X Axis

# %%
# SquareTubeXAxis

if App.ActiveDocument.getObject('SquareTubeXAxis'):
    App.ActiveDocument.getObject('SquareTubeXAxis').removeObjectsFromDocument()
    App.ActiveDocument.removeObject('SquareTubeXAxis')
    App.ActiveDocument.recompute()

App.ActiveDocument.addObject('PartDesign::Body', 'SquareTubeXAxis')
App.ActiveDocument.getObject('SquareTubeXAxis').Label = 'Square Tube X Axis'
App.ActiveDocument.recompute()

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', App.ActiveDocument.getObject('SquareTubeXAxis'))

Gui.SendMsgToActiveView("ViewFit")

# %%
# Binder001

if App.ActiveDocument.getObject('Binder001'):
    App.ActiveDocument.removeObject('Binder001')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeXAxis').newObject('PartDesign::SubShapeBinder', 'Binder001')
App.ActiveDocument.getObject('Binder001').Support = [(App.ActiveDocument.getObject('SquareTubeProfileSketch'), ('',))]
App.ActiveDocument.getObject('Binder001').Placement = App.Placement(App.Vector(0, 0, 0), App.Rotation(App.Vector(0, 0, 1), 90))
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeProfileSketch').Visibility = False

Gui.SendMsgToActiveView("ViewFit")

# %%
# Pad001

if App.ActiveDocument.getObject('Pad001'):
    App.ActiveDocument.removeObject('Pad001')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeXAxis').newObject('PartDesign::Pad', 'Pad001')
App.ActiveDocument.getObject('Pad001').Profile = App.ActiveDocument.getObject('Binder001')
App.ActiveDocument.getObject('Pad001').Length = 1500 - 2*40
App.ActiveDocument.getObject('Pad001').Midplane = True
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Binder001').Visibility = False

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', None)
Gui.SendMsgToActiveView("ViewFit")

# %%
App.ActiveDocument.getObject('SquareTubeXAxis').Visibility = False

# %% [markdown]
# # Square Tube Y Axis

# %%
# SquareTubeYAxis

if App.ActiveDocument.getObject('SquareTubeYAxis'):
    App.ActiveDocument.getObject('SquareTubeYAxis').removeObjectsFromDocument()
    App.ActiveDocument.removeObject('SquareTubeYAxis')
    App.ActiveDocument.recompute()

App.ActiveDocument.addObject('PartDesign::Body', 'SquareTubeYAxis')
App.ActiveDocument.getObject('SquareTubeYAxis').Label = 'Square Tube Y Axis'
App.ActiveDocument.recompute()

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', App.ActiveDocument.getObject('SquareTubeYAxis'))

Gui.SendMsgToActiveView("ViewFit")

# %%
# Binder002

if App.ActiveDocument.getObject('Binder002'):
    App.ActiveDocument.removeObject('Binder002')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeYAxis').newObject('PartDesign::SubShapeBinder', 'Binder002')
App.ActiveDocument.getObject('Binder002').Support = [(App.ActiveDocument.getObject('SquareTubeProfileSketch'), ('',))]
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeProfileSketch').Visibility = False

Gui.SendMsgToActiveView("ViewFit")

# %%
# Pad002

if App.ActiveDocument.getObject('Pad002'):
    App.ActiveDocument.removeObject('Pad002')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeYAxis').newObject('PartDesign::Pad', 'Pad002')
App.ActiveDocument.getObject('Pad002').Profile = App.ActiveDocument.getObject('Binder002')
App.ActiveDocument.getObject('Pad002').Length = 1500 - 2*40
App.ActiveDocument.getObject('Pad002').Midplane = True
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Binder002').Visibility = False

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', None)
Gui.SendMsgToActiveView("ViewFit")

# %%
App.ActiveDocument.getObject('SquareTubeYAxis').Visibility = False

# %% [markdown]
# # Square Tube Z Axis

# %%
# SquareTubeZAxis

if App.ActiveDocument.getObject('SquareTubeZAxis'):
    App.ActiveDocument.getObject('SquareTubeZAxis').removeObjectsFromDocument()
    App.ActiveDocument.removeObject('SquareTubeZAxis')
    App.ActiveDocument.recompute()

App.ActiveDocument.addObject('PartDesign::Body', 'SquareTubeZAxis')
App.ActiveDocument.getObject('SquareTubeZAxis').Label = 'Square Tube Z Axis'
App.ActiveDocument.recompute()

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', App.ActiveDocument.getObject('SquareTubeZAxis'))

Gui.SendMsgToActiveView("ViewFit")

# %%
# Binder003

if App.ActiveDocument.getObject('Binder003'):
    App.ActiveDocument.removeObject('Binder003')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::SubShapeBinder', 'Binder003')
App.ActiveDocument.getObject('Binder003').Support = [(App.ActiveDocument.getObject('SquareTubeProfileSketch'), ('',))]
App.ActiveDocument.getObject('Binder003').Placement = App.Placement(App.Vector(0, 0, 0), App.Rotation(App.Vector(1, 0, 0), -90))
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeProfileSketch').Visibility = False

Gui.SendMsgToActiveView("ViewFit")

# %%
# Pad003

if App.ActiveDocument.getObject('Pad003'):
    App.ActiveDocument.removeObject('Pad003')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::Pad', 'Pad003')
App.ActiveDocument.getObject('Pad003').Profile = App.ActiveDocument.getObject('Binder003')
App.ActiveDocument.getObject('Pad003').Length = 1200
App.ActiveDocument.getObject('Pad003').Midplane = True
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Binder003').Visibility = False


if App.ActiveDocument.getObject('Pad004'):
    App.ActiveDocument.removeObject('Pad004')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::Pad', 'Pad004')
App.ActiveDocument.getObject('Pad004').Profile = (App.ActiveDocument.getObject('Pad003'), ['Face18', ])
App.ActiveDocument.getObject('Pad004').Length = 40
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Pad003').Visibility = False


if App.ActiveDocument.getObject('Pad005'):
    App.ActiveDocument.removeObject('Pad005')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::Pad', 'Pad005')
App.ActiveDocument.getObject('Pad005').Profile = (App.ActiveDocument.getObject('Pad004'), ['Face4', ])
App.ActiveDocument.getObject('Pad005').Length = 40
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Pad004').Visibility = False


if App.ActiveDocument.getObject('Pad006'):
    App.ActiveDocument.removeObject('Pad006')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::Pad', 'Pad006')
App.ActiveDocument.getObject('Pad006').Profile = (App.ActiveDocument.getObject('Pad005'), ['Face12', ])
App.ActiveDocument.getObject('Pad006').Length = 400
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Pad005').Visibility = False


if App.ActiveDocument.getObject('Pad007'):
    App.ActiveDocument.removeObject('Pad007')
    App.ActiveDocument.recompute()

App.ActiveDocument.getObject('SquareTubeZAxis').newObject('PartDesign::Pad', 'Pad007')
App.ActiveDocument.getObject('Pad007').Profile = (App.ActiveDocument.getObject('Pad006'), ['Face22', ])
App.ActiveDocument.getObject('Pad007').Length = 40
App.ActiveDocument.recompute()

App.ActiveDocument.getObject('Pad006').Visibility = False


Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', None)
Gui.SendMsgToActiveView("ViewFit")

# %%
App.ActiveDocument.getObject('SquareTubeZAxis').Visibility = False

# %% [markdown]
# # Framework Assembly

# %%
# Link***XAxis, Link***YAxis and Link***ZAxis

if App.ActiveDocument.getObject('Framework'):
    App.ActiveDocument.getObject('Framework').removeObjectsFromDocument()
    App.ActiveDocument.removeObject('Framework')
    App.ActiveDocument.recompute()

App.ActiveDocument.addObject('App::Part', 'Framework')
Gui.ActiveDocument.ActiveView.setActiveObject('part', App.ActiveDocument.getObject('Framework'))
App.ActiveDocument.recompute()


# Link***XAxis

App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link001XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link002XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link003XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link004XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link005XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link006XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link007XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link008XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link009XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link010XAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link011XAxis')

App.ActiveDocument.getObject('Link001XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link002XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link003XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link004XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link005XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link006XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link007XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link008XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link009XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link010XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')
App.ActiveDocument.getObject('Link011XAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeXAxis')

App.ActiveDocument.getObject('Link002XAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/2 - 40/2')
App.ActiveDocument.getObject('Link003XAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/2 + 40/2')
App.ActiveDocument.getObject('Link004XAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/4 - 40/2')
App.ActiveDocument.getObject('Link005XAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/4 - 40/2')

App.ActiveDocument.getObject('Link006XAxis').setExpression('.Placement.Base.z', u'Pad003.Length.Value + 40')
App.ActiveDocument.getObject('Link007XAxis').setExpression('.Placement.Base.z', u'Pad003.Length.Value + 40')
App.ActiveDocument.getObject('Link007XAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/2 - 40/2')
App.ActiveDocument.getObject('Link008XAxis').setExpression('.Placement.Base.z', u'Pad003.Length.Value + 40')
App.ActiveDocument.getObject('Link008XAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/2 + 40/2')

App.ActiveDocument.getObject('Link009XAxis').setExpression('.Placement.Base.z', u'-Pad006.Length.Value - 40')
App.ActiveDocument.getObject('Link010XAxis').setExpression('.Placement.Base.z', u'-Pad006.Length.Value - 40')
App.ActiveDocument.getObject('Link010XAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/2 - 40/2')
App.ActiveDocument.getObject('Link011XAxis').setExpression('.Placement.Base.z', u'-Pad006.Length.Value - 40')
App.ActiveDocument.getObject('Link011XAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/2 + 40/2')


# Link***YAxis

App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link001YAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link002YAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link003YAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link004YAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link005YAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link006YAxis')

App.ActiveDocument.getObject('Link001YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')
App.ActiveDocument.getObject('Link002YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')
App.ActiveDocument.getObject('Link003YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')
App.ActiveDocument.getObject('Link004YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')
App.ActiveDocument.getObject('Link005YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')
App.ActiveDocument.getObject('Link006YAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeYAxis')

App.ActiveDocument.getObject('Link001YAxis').setExpression('.Placement.Base.x', u'SquareTubeXAxis.Shape.BoundBox.XLength/2 + 40/2')
App.ActiveDocument.getObject('Link002YAxis').setExpression('.Placement.Base.x', u'-SquareTubeXAxis.Shape.BoundBox.XLength/2 - 40/2')

App.ActiveDocument.getObject('Link003YAxis').setExpression('.Placement.Base.z', u'Pad003.Length.Value + 40')
App.ActiveDocument.getObject('Link003YAxis').setExpression('.Placement.Base.x', u'SquareTubeXAxis.Shape.BoundBox.XLength/2 + 40/2')
App.ActiveDocument.getObject('Link004YAxis').setExpression('.Placement.Base.z', u'Pad003.Length.Value + 40')
App.ActiveDocument.getObject('Link004YAxis').setExpression('.Placement.Base.x', u'-SquareTubeXAxis.Shape.BoundBox.XLength/2 - 40/2')

App.ActiveDocument.getObject('Link005YAxis').setExpression('.Placement.Base.z', u'-Pad006.Length.Value - 40')
App.ActiveDocument.getObject('Link005YAxis').setExpression('.Placement.Base.x', u'SquareTubeXAxis.Shape.BoundBox.XLength/2 + 40/2')
App.ActiveDocument.getObject('Link006YAxis').setExpression('.Placement.Base.z', u'-Pad006.Length.Value - 40')
App.ActiveDocument.getObject('Link006YAxis').setExpression('.Placement.Base.x', u'-SquareTubeXAxis.Shape.BoundBox.XLength/2 - 40/2')


# Link***ZAxis

App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link001ZAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link002ZAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link003ZAxis')
App.ActiveDocument.getObject('Framework').newObject('App::Link', 'Link004ZAxis')

App.ActiveDocument.getObject('Link001ZAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeZAxis')
App.ActiveDocument.getObject('Link002ZAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeZAxis')
App.ActiveDocument.getObject('Link003ZAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeZAxis')
App.ActiveDocument.getObject('Link004ZAxis').LinkedObject = App.ActiveDocument.getObject('SquareTubeZAxis')

App.ActiveDocument.getObject('Link001ZAxis').setExpression('.Placement.Base.x', u'SquareTubeXAxis.Shape.BoundBox.XLength/2 + 40/2')
App.ActiveDocument.getObject('Link001ZAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/2 + 40/2')
App.ActiveDocument.getObject('Link001ZAxis').setExpression('.Placement.Base.z', u'Pad003.Shape.BoundBox.ZLength/2 + 40/2')

App.ActiveDocument.getObject('Link002ZAxis').setExpression('.Placement.Base.x', u'SquareTubeXAxis.Shape.BoundBox.XLength/2 + 40/2')
App.ActiveDocument.getObject('Link002ZAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/2 - 40/2')
App.ActiveDocument.getObject('Link002ZAxis').setExpression('.Placement.Base.z', u'Pad003.Shape.BoundBox.ZLength/2 + 40/2')

App.ActiveDocument.getObject('Link003ZAxis').setExpression('.Placement.Base.x', u'-SquareTubeXAxis.Shape.BoundBox.XLength/2 - 40/2')
App.ActiveDocument.getObject('Link003ZAxis').setExpression('.Placement.Base.y', u'SquareTubeYAxis.Shape.BoundBox.YLength/2 + 40/2')
App.ActiveDocument.getObject('Link003ZAxis').setExpression('.Placement.Base.z', u'Pad003.Shape.BoundBox.ZLength/2 + 40/2')

App.ActiveDocument.getObject('Link004ZAxis').setExpression('.Placement.Base.x', u'-SquareTubeXAxis.Shape.BoundBox.XLength/2 - 40/2')
App.ActiveDocument.getObject('Link004ZAxis').setExpression('.Placement.Base.y', u'-SquareTubeYAxis.Shape.BoundBox.YLength/2 - 40/2')
App.ActiveDocument.getObject('Link004ZAxis').setExpression('.Placement.Base.z', u'Pad003.Shape.BoundBox.ZLength/2 + 40/2')


App.ActiveDocument.recompute()

Gui.ActiveDocument.ActiveView.setActiveObject('part', None)
Gui.SendMsgToActiveView("ViewFit")

# %%
# Save

Gui.ActiveDocument.ActiveView.setActiveObject('pdbody', None)
Gui.ActiveDocument.ActiveView.setActiveObject('part', None)

Gui.ActiveDocument.ActiveView.viewDefaultOrientation()
Gui.ActiveDocument.ActiveView.setCameraType("Perspective")
Gui.SendMsgToActiveView("ViewFit")

App.ActiveDocument.recompute()

App.ActiveDocument.saveAs("./Framework/Framework.FCStd")
